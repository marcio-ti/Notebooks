# %% [markdown]
# ## **📌 Questões - Visualização de Séries Temporais com Matplotlib e Seaborn**
#
# ### **🔹 Básico** (1 a 10)
#
# 1. Como criar um gráfico de linha simples usando o Matplotlib para visualizar uma série temporal univariada?
# 2. Qual a função do `plt.plot()` no Matplotlib e como ela pode ser utilizada para representar séries temporais?
# 3. Como adicionar rótulos de título e eixos a um gráfico de linha em Matplotlib?
# 4. O que é um gráfico de dispersão e como ele pode ser criado utilizando `plt.scatter()` no Matplotlib?
# 5. Como personalizar as cores e estilos de linha em um gráfico de linha no Matplotlib?
# 6. Como ajustar o tamanho do gráfico de linha usando o Matplotlib?
# 7. Quais parâmetros do `plt.plot()` permitem modificar a aparência do gráfico, como estilo de linha, cor e marcadores?
# 8. O que é um gráfico de tendências em séries temporais e como ele pode ser visualizado com Matplotlib?
# 9. Como alterar o estilo de um gráfico de linha para incluir marcadores e linhas tracejadas?
# 10. Como utilizar o `seaborn.lineplot()` para criar um gráfico de linha estilizado?
#
# ---
#
# ### **🔹 Intermediário** (11 a 20)
#
# 11. Como você pode ajustar o intervalo de tempo no eixo X de um gráfico de linha usando Matplotlib?
# 12. Explique como personalizar a escala de um gráfico de linha, como usando `set_yscale()` e `set_xscale()` para ajustar as escalas dos eixos X e Y.
# 13. Como você pode adicionar uma linha de tendência (regressão linear) a um gráfico de séries temporais com o Matplotlib?
# 14. Quais são os métodos de personalização do gráfico de linhas em Matplotlib que permitem ajustar a espessura e o estilo das linhas?
# 15. Como adicionar uma legenda ao gráfico de linha em Matplotlib para indicar diferentes séries temporais?
# 16. Como criar múltiplos gráficos de linha em um único gráfico, compartilhando o mesmo eixo X?
# 17. Explique o uso de `seaborn.scatterplot()` para visualizar a relação entre variáveis temporais em um gráfico de dispersão.
# 18. Como criar um gráfico de autocorrelação (ACF) de uma série temporal usando o Matplotlib?
# 19. Como fazer a personalização de gráficos de dispersão com Seaborn, ajustando cores, tamanhos de pontos e transparência?
# 20. Como você pode representar a sazonalidade de uma série temporal com gráficos de linhas utilizando Seaborn?
#
# ---
#
# ### **🔹 Avançado** (21 a 40)
#
# 21. Como criar um gráfico de dispersão para comparar duas séries temporais com Seaborn e Matplotlib?
# 22. Explique como usar `sns.lineplot()` para criar gráficos de linha com uma coluna de datas e valores de séries temporais.
# 23. Como você pode incluir uma linha de tendência ajustada no gráfico de dispersão para entender melhor a relação entre as variáveis temporais?
# 24. O que é o gráfico de autocorrelação (ACF) e como ele pode ser gerado usando `plot_acf()` do `statsmodels`?
# 25. Como personalizar o gráfico de autocorrelação (ACF) com `plot_acf()` para exibir diferentes lags e intervalos de confiança?
# 26. Como criar um gráfico de autocorrelação parcial (PACF) e o que ele revela sobre as dependências temporais da série?
# 27. Como você pode usar o `sns.pairplot()` para visualizar a relação entre múltiplas séries temporais e suas correlações?
# 28. Como melhorar a legibilidade de um gráfico de série temporal ao ajustar o limite dos eixos em Matplotlib?
# 29. Explique como a função `rolling()` pode ser utilizada para criar gráficos de média móvel de uma série temporal.
# 30. Como criar gráficos de tendências e sazonalidades de uma série temporal, removendo o componente de tendência?
# 31. Como representar séries temporais com alta frequência de dados (exemplo: dados por hora) em gráficos de linha, garantindo legibilidade?
# 32. Como usar a função `plt.subplot()` para gerar múltiplos gráficos em uma única figura ao visualizar séries temporais?
# 33. Quais são os benefícios de utilizar o `sns.heatmap()` para visualizar correlações temporais entre diferentes variáveis?
# 34. Como você pode ajustar o formato das legendas e rótulos dos eixos para melhorar a apresentação do gráfico de série temporal?
# 35. Como criar gráficos interativos com o Matplotlib e o `mplcursors` para visualizar séries temporais de maneira dinâmica?
# 36. Como realizar a normalização de séries temporais para visualização em gráficos de linhas múltiplas no mesmo eixo?
# 37. Explique como gerar gráficos de tendências de longo prazo com a função `seaborn.lineplot()` usando agregações diárias ou mensais.
# 38. Como usar o `sns.FacetGrid()` para criar visualizações segmentadas de múltiplas séries temporais em um único gráfico?
# 39. Como você pode comparar a sazonalidade de diferentes séries temporais em um gráfico de linhas múltiplas com Seaborn?
# 40. Explique como personalizar o gráfico de autocorrelação parcial (PACF) e ajustar os parâmetros de lags e intervalo de confiança com o `plot_pacf()` do `statsmodels`.
#
# ---
#
# ## **⚡ Desafios Avançados**
#
# 41. **Gráfico de Linhas Personalizado**: Crie um gráfico de linhas utilizando Matplotlib com diferentes estilos de linha, cores e marcadores para representar múltiplas séries temporais, ajustando o eixo X para datas.
# 42. **Visualização de Sazonalidade**: Realize a decomposição de uma série temporal utilizando o `seasonal_decompose()` do `statsmodels` e visualize a tendência, a sazonalidade e o ruído com gráficos de linha.
# 43. **Gráfico de ACF e PACF**: Utilize o `plot_acf()` e `plot_pacf()` para visualizar as autocorrelações e correlações parciais de uma série temporal, e analise como isso pode ajudar na escolha de um modelo ARIMA.
# 44. **Gráfico de Dispersão com Linhas de Tendência**: Crie um gráfico de dispersão entre duas séries temporais com Seaborn e adicione uma linha de tendência ajustada (regressão linear) para avaliar a relação entre elas.
# 45. **Visualização de Séries Temporais Multivariadas**: Utilize o `sns.pairplot()` para visualizar a relação entre múltiplas séries temporais e suas correlações, personalizando as cores para diferenciar as variáveis.
# 46. **Autocorrelação em Séries Temporais**: Crie um gráfico de autocorrelação (ACF) com lags específicos e intervalos de confiança ajustados para avaliar a dependência temporal em uma série.
# 47. **Comparação de Sazonalidades**: Crie múltiplos gráficos de linha representando diferentes séries temporais e compare suas sazonalidades para verificar padrões comuns utilizando Matplotlib e Seaborn.
# 48. **Gráfico de Tendência de Longo Prazo**: Realize uma agregação de uma série temporal de alta frequência para visualizar tendências de longo prazo, como por meio de médias móveis mensais ou anuais.
# 49. **Visualização de Correlação com Heatmap**: Crie um gráfico de correlação entre várias séries temporais utilizando `sns.heatmap()` e analise as relações entre as variáveis.
# 50. **Gráfico de Linhas com Subplots**: Utilize `plt.subplot()` para gerar múltiplos gráficos de linhas em uma única figura, representando diferentes aspectos de uma série temporal, como tendência, sazonalidade e ruído.
#
# ---
#
# Essas questões e desafios cobrem os **principais aspectos de visualização de séries temporais** com **Matplotlib** e **Seaborn**, incluindo gráficos de linha, dispersão, autocorrelação, tendências e sazonalidades. 🚀📊
#
# Se precisar de mais detalhes ou tiver dúvidas sobre algum exercício, estou à disposição! 😊
