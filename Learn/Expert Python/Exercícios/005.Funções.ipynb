# %% [markdown]
# Aqui está uma coleção de **50 exercícios focados em funções** no Python, organizados por níveis de dificuldade, abrangendo conceitos básicos, intermediários e avançados.
#
# ---
#
# ## **Básico**
# ### **Definição de Funções**
# 1. Crie uma função que receba um número e retorne seu dobro.
# 2. Escreva uma função que receba uma string e retorne seu comprimento.
# 3. Desenvolva uma função que receba dois números e retorne a soma deles.
# 4. Implemente uma função que receba uma lista de números e retorne a soma total.
# 5. Crie uma função que receba um número e retorne se ele é par ou ímpar.
#
# ### **Funções com Condicionais**
# 6. Crie uma função que determine se um número é positivo, negativo ou zero.
# 7. Escreva uma função que receba a idade de uma pessoa e retorne se ela pode dirigir.
# 8. Desenvolva uma função que receba três números e retorne o maior deles.
# 9. Crie uma função que verifique se uma string contém a letra "e".
# 10. Escreva uma função que retorne "Aprovado" ou "Reprovado" com base na nota de um aluno (nota >= 7).
#
# ### **Funções com Loops**
# 11. Escreva uma função que receba um número e retorne seu fatorial.
# 12. Crie uma função que gere a sequência de Fibonacci até um determinado número.
# 13. Desenvolva uma função que receba uma string e conte o número de vogais.
# 14. Implemente uma função que receba uma lista de números e retorne uma nova lista com apenas os números pares.
# 15. Crie uma função que calcule o produto de todos os números em uma lista.
#
# ---
#
# ## **Intermediário**
# ### **Funções com Retorno e Parâmetros**
# 16. Escreva uma função que receba o nome, a idade e a cidade de uma pessoa e retorne uma frase formatada como: `"Meu nome é [nome], tenho [idade] anos e moro em [cidade]."`
# 17. Crie uma função que receba uma lista de strings e retorne apenas aquelas que têm mais de 5 caracteres.
# 18. Desenvolva uma função que receba uma lista de números e retorne o maior e o menor número.
# 19. Implemente uma função que receba uma lista de números e retorne outra lista com os números elevados ao quadrado.
# 20. Crie uma função que receba uma string e retorne a string invertida.
#
# ### **Funções com Dicionários**
# 21. Escreva uma função que receba um dicionário com notas de alunos e retorne os nomes dos aprovados (nota >= 7).
# 22. Crie uma função que receba um dicionário e retorne a soma de todos os valores.
# 23. Desenvolva uma função que inverta as chaves e valores de um dicionário.
# 24. Implemente uma função que receba um dicionário e retorne apenas os pares chave-valor onde o valor é maior que 10.
# 25. Crie uma função que verifique se uma chave específica está presente em um dicionário.
#
# ### **Funções com Condições e Loops**
# 26. Escreva uma função que determine se uma string é um palíndromo.
# 27. Crie uma função que receba uma lista de números e remova todos os números duplicados.
# 28. Desenvolva uma função que conte a frequência de cada caractere em uma string.
# 29. Implemente uma função que receba dois números e retorne o maior divisor comum (MDC) entre eles.
# 30. Crie uma função que receba duas listas e retorne os elementos que elas têm em comum.
#
# ---
#
# ## **Avançado**
# ### **Funções Aninhadas**
# 31. Crie uma função que calcule o quadrado de um número usando outra função interna.
# 32. Desenvolva uma função que receba uma string e use uma função interna para contar as vogais.
# 33. Escreva uma função que use uma função interna para verificar se todos os números de uma lista são positivos.
# 34. Implemente uma função que use outra função interna para calcular a média de uma lista de números.
# 35. Crie uma função que receba uma string e use uma função interna para capitalizar cada palavra.
#
# ### **Funções com Recursão**
# 36. Implemente uma função recursiva para calcular o fatorial de um número.
# 37. Escreva uma função recursiva que conte quantos dígitos há em um número.
# 38. Crie uma função recursiva que gere a sequência de Fibonacci até um número dado.
# 39. Desenvolva uma função recursiva que retorne o maior número em uma lista.
# 40. Implemente uma função recursiva que conte quantas vezes um caractere aparece em uma string.
#
# ### **Funções com Parâmetros e Retorno Avançados**
# 41. Crie uma função que receba argumentos posicionais e de palavra-chave e os imprima de forma organizada.
# 42. Desenvolva uma função que receba uma lista de números e use `*args` para calcular sua soma total.
# 43. Escreva uma função que use `**kwargs` para formatar informações pessoais em uma frase.
# 44. Crie uma função que use `lambda` para ordenar uma lista de dicionários por uma chave específica.
# 45. Desenvolva uma função que retorne outra função que eleva números a uma potência específica.
#
# ### **Desafios Avançados**
# 46. Crie uma função que receba uma lista e retorne outra lista com os números ordenados sem usar `sorted()`.
# 47. Desenvolva uma função que calcule a média, a mediana e a moda de uma lista de números.
# 48. Implemente uma função que simule o lançamento de dois dados e calcule a soma de suas faces.
# 49. Escreva uma função que receba um número e retorne sua representação binária como string.
# 50. Crie uma função que gere todas as permutações possíveis de uma string.
#
# ---
#
# Se precisar de soluções ou explicações detalhadas para qualquer exercício, é só pedir! 😊
