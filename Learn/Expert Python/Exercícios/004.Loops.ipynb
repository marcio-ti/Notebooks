# %% [markdown]
# Aqui está uma coleção de **50 exercícios focados em Loops** no Python, organizados por níveis de dificuldade e cobrindo diferentes tipos de laços como `for`, `while`, e suas combinações com listas, dicionários, strings e mais:
#
# ---
#
# ## **Básico**
# ### **Loops com listas**
# 1. Use um loop `for` para imprimir cada elemento de uma lista de números.
# 2. Use um loop `while` para somar todos os números de uma lista até que encontre um número negativo.
# 3. Faça um loop que imprima os números de 1 a 10.
# 4. Crie uma lista de frutas e use um loop para imprimir cada fruta.
# 5. Imprima o índice e o valor de cada elemento de uma lista usando `enumerate()`.
#
# ### **Loops com strings**
# 6. Use um loop para contar quantas vogais há em uma string.
# 7. Faça um loop para inverter uma string sem usar métodos prontos.
# 8. Use um loop para verificar se uma palavra é um palíndromo.
# 9. Imprima apenas os caracteres maiúsculos de uma string usando um loop.
# 10. Substitua todas as ocorrências de uma letra específica em uma string por outra letra.
#
# ### **Loops com números**
# 11. Use um loop `for` para calcular o fatorial de um número.
# 12. Faça um loop para somar os números pares de 1 a 100.
# 13. Imprima os números ímpares de 1 a 50 usando um loop.
# 14. Verifique se um número é primo usando um loop.
# 15. Use um loop para gerar uma tabuada de multiplicação de 1 a 10.
#
# ---
#
# ## **Intermediário**
# ### **Loops com listas e condicionais**
# 16. Filtre apenas os números maiores que 10 de uma lista usando um loop.
# 17. Use um loop para remover todos os elementos duplicados de uma lista.
# 18. Crie uma nova lista com o quadrado de cada número de uma lista existente.
# 19. Conte quantas vezes cada número aparece em uma lista usando um loop.
# 20. Inverta a ordem de uma lista usando um loop.
#
# ### **Loops com dicionários**
# 21. Itere sobre as chaves de um dicionário e imprima cada uma.
# 22. Itere sobre os valores de um dicionário e calcule a soma total.
# 23. Crie um loop que troque as chaves e valores de um dicionário.
# 24. Filtre apenas os pares chave-valor onde o valor seja maior que 10.
# 25. Crie um dicionário que conte a frequência de cada letra em uma string.
#
# ### **Nested Loops (Loops aninhados)**
# 26. Imprima um padrão triangular de estrelas:
#     ```
#     *
#     **
#     ***
#     ****
#     *****
#     ```
# 27. Use loops aninhados para gerar a matriz identidade de ordem 3x3.
# 28. Crie um programa que gere todas as combinações possíveis de dois números de 1 a 5.
# 29. Crie uma tabela de multiplicação de 1 a 5 usando loops aninhados.
# 30. Faça um programa que verifique se duas listas têm elementos em comum, usando loops aninhados.
#
# ---
#
# ## **Avançado**
# ### **Loops com funções**
# 31. Crie uma função que receba uma lista e retorne a soma de seus números usando um loop.
# 32. Desenvolva uma função que retorne os índices de um valor em uma lista, usando um loop.
# 33. Escreva uma função que gere os `n` primeiros números da sequência de Fibonacci usando um loop.
# 34. Crie uma função que receba uma string e retorne outra string com os caracteres invertidos, usando um loop.
# 35. Escreva uma função que use um loop para verificar se um número é um quadrado perfeito.
#
# ### **Loops com controle de fluxo**
# 36. Use `break` para interromper um loop quando um número negativo for encontrado em uma lista.
# 37. Use `continue` para pular números ímpares em uma sequência de 1 a 20.
# 38. Use `else` em um loop para imprimir "Todos os números são positivos" se nenhum número negativo for encontrado.
# 39. Simule um sistema de login onde o usuário tem 3 tentativas usando um loop.
# 40. Gere números aleatórios de 1 a 10 até que o número 7 seja gerado, e então pare o loop.
#
# ### **Desafios avançados**
# 41. Use loops para calcular a soma de uma série matemática:
#     \( S = 1 + \frac{1}{2} + \frac{1}{3} + ... + \frac{1}{n} \), onde \( n \) é fornecido pelo usuário.
# 42. Implemente um programa que crie uma "pirâmide invertida" de números:
#     ```
#     54321
#     4321
#     321
#     21
#     1
#     ```
# 43. Crie um loop que encontre o maior divisor comum (MDC) de dois números.
# 44. Gere todos os números de 1 a 100 que são múltiplos de 3 e 5, mas use apenas um loop.
# 45. Use um loop para determinar o maior número em uma lista sem usar funções prontas como `max()`.
#
# ### **Projetos desafiadores com loops**
# 46. Crie um programa que calcule a média de notas de uma classe e determine os alunos aprovados.
# 47. Desenvolva um programa que simule o lançamento de dois dados até que o total seja 7.
# 48. Faça um programa que leia números inseridos pelo usuário até que ele digite `0`, e então imprima a soma total.
# 49. Use um loop para criptografar uma mensagem simples, deslocando cada letra por 3 posições no alfabeto.
# 50. Escreva um programa que gere um padrão de tabuleiro de xadrez:
#     ```
#     # # # #
#      # # # #
#     # # # #
#      # # # #
#     ```
#
# ---
#
# Se precisar de exemplos resolvidos ou ajuda em algum exercício específico, é só pedir! 😊
