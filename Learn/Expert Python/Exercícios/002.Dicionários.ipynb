# %% [markdown]
# Aqui está uma coleção de 50 exercícios focados em **dicionários** no Python, organizados por níveis de dificuldade e cobrindo diversas operações e funcionalidades:
#
# ---
#
# ## **Básico**
# ### **Manipulação de dicionários**
# 1. Crie um dicionário com as chaves `"nome"`, `"idade"`, e `"cidade"`, e preencha com valores fictícios.
# 2. Adicione uma nova chave `"profissão"` ao dicionário criado no exercício anterior.
# 3. Remova a chave `"cidade"` de um dicionário.
# 4. Acesse e imprima o valor da chave `"idade"` de um dicionário.
# 5. Verifique se a chave `"email"` está presente em um dicionário.
#
# ### **Operações com dicionários**
# 6. Imprima todas as chaves de um dicionário.
# 7. Imprima todos os valores de um dicionário.
# 8. Converta um dicionário em uma lista de tuplas usando o método apropriado.
# 9. Crie um dicionário vazio e adicione 5 pares de chave-valor dinamicamente.
# 10. Inverta as chaves e valores de um dicionário.
#
# ### **List Comprehensions com dicionários**
# 11. Crie um dicionário onde as chaves sejam números de 1 a 5 e os valores seus quadrados.
# 12. A partir de uma lista `["a", "b", "c"]`, crie um dicionário onde cada elemento da lista é uma chave, e o valor é o índice.
# 13. Gere um dicionário com os números de 1 a 10 como chaves e "Par" ou "Ímpar" como valores, dependendo do número.
# 14. Dado um dicionário, crie outro dicionário contendo apenas os itens cujo valor seja maior que 10.
# 15. Converta duas listas `[1, 2, 3]` e `["um", "dois", "três"]` em um dicionário.
#
# ---
#
# ## **Intermediário**
# ### **Condicionais e dicionários**
# 16. Escreva um programa que adicione uma chave a um dicionário apenas se ela não existir.
# 17. Verifique se todos os valores em um dicionário são do tipo `int`.
# 18. Substitua todos os valores de um dicionário por seus quadrados.
# 19. Remova todas as chaves de um dicionário cujos valores sejam nulos ou vazios.
# 20. Crie um programa que encontre a chave com o maior valor em um dicionário.
#
# ### **Loops e dicionários**
# 21. Some todos os valores de um dicionário.
# 22. Encontre a chave com o menor valor em um dicionário.
# 23. Faça a contagem de ocorrências de cada letra em uma string usando um dicionário.
# 24. Crie um dicionário a partir de uma lista de palavras, onde cada palavra é uma chave e o valor é o número de caracteres.
# 25. Reordene um dicionário com base nos valores, em ordem decrescente.
#
# ### **List Comprehensions com dicionários avançadas**
# 26. Dado um dicionário, crie outro com as chaves em letras maiúsculas.
# 27. Gere um dicionário com números de 1 a 10, onde o valor seja `"Par"` ou `"Ímpar"`, mas exclua os números múltiplos de 3.
# 28. Converta um dicionário de preços em outro aplicando 10% de desconto nos valores.
# 29. Dado um dicionário, filtre apenas as chaves que começam com uma vogal.
# 30. Crie um dicionário com a soma acumulada dos valores de uma lista de números.
#
# ---
#
# ## **Avançado**
# ### **Manipulação complexa de dicionários**
# 31. Combine dois dicionários somando os valores das chaves iguais.
# 32. Converta uma lista de dicionários em um único dicionário agrupado por uma chave comum.
# 33. Escreva um programa que ordene as chaves de um dicionário com base em seus valores.
# 34. Crie um dicionário que contenha como valores listas de números múltiplos de 2, 3 e 5 até 50.
# 35. Gere um dicionário onde as chaves sejam palavras de uma frase e os valores sejam a quantidade de vezes que elas aparecem.
#
# ### **Funções e dicionários**
# 36. Crie uma função que receba um dicionário e retorne uma lista com as chaves duplicadas (se existirem).
# 37. Desenvolva uma função que retorne as chaves de um dicionário cujos valores sejam strings.
# 38. Escreva uma função que receba um dicionário e divida os valores em dois grupos: pares e ímpares.
# 39. Faça uma função que receba um dicionário e multiplique todos os valores numéricos por um fator dado.
# 40. Escreva uma função que calcule a frequência de cada letra em uma frase.
#
# ### **Desafios avançados**
# 41. Crie um dicionário que represente um grafo simples com nós e arestas.
# 42. Desenvolva uma função que inverta as chaves e valores de um dicionário, mas transforme os valores em listas, agrupando os itens com a mesma chave.
# 43. Escreva um programa que crie um dicionário onde as chaves sejam nomes de arquivos em uma pasta e os valores seus tamanhos em bytes.
# 44. Gere um dicionário que associe cada número de 1 a 100 à sua representação em binário.
# 45. Crie uma função que identifique dicionários semelhantes (mesmas chaves e valores).
#
# ### **Desafios adicionais**
# 46. Desenvolva uma função que verifique se dois dicionários têm as mesmas chaves e valores.
# 47. Escreva um programa que conte a frequência de cada valor em um dicionário.
# 48. Faça uma função que divida um dicionário em dois, com base em um critério aplicado aos valores.
# 49. Implemente uma função que calcule a interseção entre dois dicionários (chaves e valores).
# 50. Crie um dicionário de um dicionário (nested dictionary) que organize informações como nome, idade, cidade, e profissão para várias pessoas.
#
# ---
#
# Se precisar de mais exercícios ou versões resolvidas, estou à disposição! 😊

# %% [markdown]
# Ordenando um Dicionário por Valor em Python

# %% [markdown]
# ### Exercícios: Ordenando Dicionários por Valor em Python
#
# 1. **Exercício Básico**
#    Dado o dicionário abaixo, ordene-o por valor em ordem crescente:
#    ```python
#    fruits = {'apple': 5, 'banana': 2, 'cherry': 8, 'date': 4}
#    ```
#
# ---
#
# 2. **Ordem Decrescente**
#    Usando `sorted()`, ordene o dicionário abaixo por valor em ordem decrescente:
#    ```python
#    scores = {'Alice': 10, 'Bob': 15, 'Charlie': 8, 'Diana': 20}
#    ```
#
# ---
#
# 3. **Extraindo apenas as chaves**
#    Ordene o dicionário a seguir por valor e retorne apenas as chaves em uma lista:
#    ```python
#    items = {'pen': 3, 'notebook': 7, 'eraser': 2, 'marker': 5}
#    ```
#
# ---
#
# 4. **Transformar de volta em dicionário**
#    Após ordenar o dicionário abaixo por valor, converta o resultado de volta para um dicionário ordenado:
#    ```python
#    prices = {'bread': 12, 'milk': 8, 'cheese': 20, 'butter': 15}
#    ```
#
# ---
#
# 5. **Ordenação de Valores Negativos**
#    Ordene o dicionário abaixo por valor em ordem crescente, considerando que os valores são negativos:
#    ```python
#    debts = {'John': -200, 'Anna': -100, 'Mike': -150, 'Lisa': -50}
#    ```
#
# ---
#
# 6. **Ordenação de Tuplas Complexas**
#    Ordene o dicionário por valor, onde o valor é uma tupla. Ordene com base no primeiro elemento da tupla:
#    ```python
#    data = {'a': (3, 7), 'b': (1, 4), 'c': (2, 8), 'd': (5, 2)}
#    ```
#
# ---
#
# 7. **Filtrando durante a ordenação**
#    Ordene o dicionário abaixo por valor, mas exclua os pares cujo valor seja menor que 50:
#    ```python
#    donations = {'Alice': 30, 'Bob': 60, 'Charlie': 50, 'Diana': 70}
#    ```
#
# ---
#
# 8. **Ordenando por Valor Absoluto**
#    Ordene o dicionário abaixo por valor em ordem crescente, considerando o valor absoluto:
#    ```python
#    balances = {'a': -100, 'b': 50, 'c': -25, 'd': 75}
#    ```
#
# ---
#
# 9. **Ordenando Chaves com o Mesmo Valor**
#    Ordene o dicionário abaixo por valor. Para valores iguais, ordene as chaves em ordem alfabética:
#    ```python
#    grades = {'Anna': 85, 'Bob': 90, 'Charlie': 85, 'Diana': 90}
#    ```
#
# ---
#
# 10. **Ordenação com Multicritérios**
#    Ordene o dicionário abaixo por valor em ordem crescente. Em caso de empate, ordene pela chave em ordem decrescente:
#    ```python
#    sales = {'x': 50, 'y': 75, 'z': 50, 'w': 100}
#    ```
