# %% [markdown]
# Aqui estão **50 exercícios focados em processamento de dados** em Python, cobrindo JSON, textos, números e outros tipos de dados, sem o uso de bibliotecas externas.
#
# ---
#
# ## **Básico**
# ### **Processamento de Textos**
# 1. Escreva uma função que conte quantas palavras existem em uma string.
# 2. Crie uma função que remova os espaços em branco extras de uma string.
# 3. Escreva uma função que substitua todas as ocorrências de uma palavra em um texto por outra.
# 4. Desenvolva uma função que receba uma string e retorne apenas os caracteres alfabéticos.
# 5. Escreva uma função que divida uma string em frases, considerando o ponto final como separador.
#
# ### **Processamento de Números**
# 6. Crie uma função que calcule a soma dos dígitos de um número inteiro.
# 7. Desenvolva uma função que receba um número e retorne `True` se ele for primo, ou `False` caso contrário.
# 8. Implemente uma função que converta um número inteiro em binário sem usar funções prontas.
# 9. Crie uma função que receba dois números e retorne a média aritmética deles.
# 10. Desenvolva uma função que verifique se um número é um quadrado perfeito.
#
# ### **Processamento de JSON (Dicionários)**
# 11. Escreva uma função que extraia todas as chaves de um dicionário aninhado.
# 12. Crie uma função que receba um dicionário e retorne uma lista com todos os valores.
# 13. Desenvolva uma função que remova uma chave específica de um dicionário.
# 14. Escreva uma função que atualize o valor de uma chave específica em um dicionário.
# 15. Crie uma função que conte quantas chaves existem em um dicionário aninhado.
#
# ---
#
# ## **Intermediário**
# ### **Processamento de Textos**
# 16. Escreva uma função que inverta a ordem das palavras em uma string.
# 17. Crie uma função que receba uma lista de strings e retorne a maior string.
# 18. Desenvolva uma função que conte a frequência de cada palavra em um texto.
# 19. Escreva uma função que encontre a palavra mais longa em um texto.
# 20. Implemente uma função que retorne todas as palavras únicas de uma string.
#
# ### **Processamento de Números**
# 21. Crie uma função que receba uma lista de números e retorne os números pares.
# 22. Desenvolva uma função que calcule o desvio padrão de uma lista de números.
# 23. Escreva uma função que identifique o segundo maior número em uma lista.
# 24. Implemente uma função que verifique se uma lista de números está ordenada em ordem crescente.
# 25. Crie uma função que calcule o produto de todos os números em uma lista.
#
# ### **Processamento de JSON (Dicionários)**
# 26. Escreva uma função que calcule a soma de todos os valores em um dicionário, assumindo que todos os valores são numéricos.
# 27. Crie uma função que receba um dicionário e retorne um novo dicionário com as chaves e valores invertidos.
# 28. Desenvolva uma função que combine dois dicionários em um só.
# 29. Escreva uma função que filtre pares chave-valor de um dicionário com base em um critério (ex.: valores maiores que 10).
# 30. Crie uma função que ache o caminho para um valor específico em um dicionário aninhado.
#
# ---
#
# ## **Avançado**
# ### **Processamento de Textos**
# 31. Escreva uma função que implemente um algoritmo de busca para encontrar todas as ocorrências de uma palavra em um texto e retorne seus índices.
# 32. Crie uma função que implemente um "auto-corrector" básico, substituindo palavras incorretas por versões corretas com base em um dicionário pré-definido.
# 33. Desenvolva uma função que analise a complexidade de um texto, calculando a média de palavras por frase.
# 34. Implemente uma função que gere um resumo de um texto, retornando apenas as `n` frases mais longas.
# 35. Escreva uma função que detecte e remova palavras repetidas consecutivas de um texto.
#
# ### **Processamento de Números**
# 36. Crie uma função que calcule o valor absoluto de um número sem usar funções prontas.
# 37. Desenvolva uma função que receba uma lista de números e retorne a mediana.
# 38. Escreva uma função que divida uma lista de números em duas partes iguais (ou quase iguais).
# 39. Implemente uma função que calcule a soma dos números em uma matriz (lista de listas).
# 40. Crie uma função que encontre o menor número em uma matriz.
#
# ### **Processamento de JSON (Dicionários)**
# 41. Escreva uma função que aplique uma transformação a todos os valores de um dicionário (ex.: duplicar valores numéricos).
# 42. Crie uma função que mescle vários dicionários em um único dicionário.
# 43. Desenvolva uma função que remova todas as chaves de um dicionário cujos valores sejam `None`.
# 44. Implemente uma função que ordene um dicionário por seus valores.
# 45. Escreva uma função que "achate" um dicionário aninhado em um único nível, usando chaves compostas.
#
# ---
#
# ## **Desafios Avançados**
# 46. Escreva uma função que implemente a compactação de texto básica (ex.: transformar "aaabbc" em "a3b2c1").
# 47. Crie uma função que implemente a descompactação de texto compactado (ex.: transformar "a3b2c1" em "aaabbc").
# 48. Desenvolva uma função que avalie uma expressão matemática simples fornecida como string (ex.: "3 + 5 * 2").
# 49. Implemente um parser básico para JSON em formato de string, retornando um dicionário.
# 50. Escreva uma função que encontre o menor caminho entre dois nós em um grafo representado por um dicionário.
#
# ---
#
# Se precisar de exemplos resolvidos ou explicações sobre algum exercício, é só avisar! 😊
