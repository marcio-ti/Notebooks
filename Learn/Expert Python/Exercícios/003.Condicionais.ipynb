# %% [markdown]
# Aqui está uma coleção de **50 exercícios focados em condicionais** no Python, organizados por níveis de dificuldade e cobrindo diversas situações onde condicionais são aplicados:
#
# ---
#
# ## **Básico**
# ### **If-Else Simples**
# 1. Verifique se um número é positivo, negativo ou zero.
# 2. Peça ao usuário para inserir um número e exiba se é par ou ímpar.
# 3. Determine se um número é maior que 10.
# 4. Verifique se uma string contém a letra `"a"`.
# 5. Escreva um programa que verifica se um número está no intervalo de 1 a 100.
#
# ### **If-Elif-Else**
# 6. Crie um programa que peça uma nota e exiba a classificação:
#    - `>= 9`: "Excelente"
#    - `>= 7`: "Bom"
#    - `>= 5`: "Regular"
#    - `< 5`: "Insuficiente"
# 7. Verifique se um ano é bissexto.
# 8. Peça ao usuário para inserir a idade e determine se ele pode votar:
#    - Menor de 16: "Não pode votar"
#    - 16 ou 17: "Voto facultativo"
#    - Maior ou igual a 18: "Voto obrigatório"
# 9. Verifique se três números formam um triângulo e informe o tipo de triângulo:
#    - Equilátero, Isósceles ou Escaleno.
# 10. Peça ao usuário para inserir uma letra e verifique se é uma vogal ou consoante.
#
# ---
#
# ## **Intermediário**
# ### **Condicionais com Operadores Lógicos**
# 11. Verifique se um número está entre 10 e 20, inclusive.
# 12. Determine se uma pessoa pode se aposentar com base na idade e no tempo de contribuição.
# 13. Crie um programa que verifica se uma senha inserida pelo usuário corresponde à senha `"Python123"`.
# 14. Verifique se um número é múltiplo de 3 e 5 simultaneamente.
# 15. Determine se um aluno passou em uma disciplina com base em duas notas e se ele tem pelo menos 75% de presença.
#
# ### **Condicionais Aninhados**
# 16. Peça ao usuário para inserir dois números e determine:
#     - Se ambos são pares.
#     - Se ambos são ímpares.
#     - Se um é par e o outro ímpar.
# 17. Verifique se um número é positivo, negativo ou zero e, se positivo, se é maior que 100.
# 18. Classifique um carro como "econômico", "regular" ou "gastador" com base no consumo em km/l:
#     - `>= 15`: Econômico
#     - `>= 10 e < 15`: Regular
#     - `< 10`: Gastador.
# 19. Determine se uma string é curta, média ou longa:
#     - Menor que 5 caracteres: Curta.
#     - Entre 5 e 10 caracteres: Média.
#     - Mais de 10 caracteres: Longa.
# 20. Verifique se três lados formam um triângulo. Caso positivo, determine se ele é reto.
#
# ### **Condicionais com Listas**
# 21. Verifique se um número está presente em uma lista.
# 22. Determine o maior número de uma lista com base em condicionais.
# 23. Verifique se todos os elementos de uma lista são positivos.
# 24. Classifique uma lista de números como homogênea (todos pares ou todos ímpares) ou mista.
# 25. Peça ao usuário para inserir uma lista de números e determine quantos deles são maiores que 10.
#
# ---
#
# ## **Avançado**
# ### **Condicionais com Funções**
# 26. Crie uma função que receba um número e retorne `"Positivo"`, `"Negativo"` ou `"Zero"`.
# 27. Implemente uma função que receba três números e retorne o maior deles.
# 28. Escreva uma função que verifique se uma string é um palíndromo.
# 29. Desenvolva uma função que determine se um número é primo.
# 30. Crie uma função que avalie a elegibilidade de um candidato a um emprego com base na idade, experiência e habilidades.
#
# ### **Condicionais com Dicionários**
# 31. Verifique se uma chave está presente em um dicionário.
# 32. Determine se todos os valores de um dicionário são maiores que um determinado número.
# 33. Peça ao usuário para inserir uma nota e retorne a avaliação correspondente de um dicionário:
#     - `{"A": "Excelente", "B": "Bom", "C": "Regular", "D": "Insuficiente"}`.
# 34. Escreva um programa que atualize o valor de uma chave em um dicionário apenas se a nova entrada for maior que o valor atual.
# 35. Crie um dicionário com alunos e suas médias, e imprima apenas os aprovados (média >= 7).
#
# ### **Desafios com Operadores Ternários**
# 36. Use o operador ternário para verificar se um número é par ou ímpar.
# 37. Determine se uma string é vazia ou não usando um operador ternário.
# 38. Verifique se um número é divisível por 3 usando um operador ternário.
# 39. Crie uma lista com `"Aprovado"` ou `"Reprovado"` para cada nota em uma lista, usando operador ternário.
# 40. Verifique se uma pessoa pode dirigir com base na idade e na posse de habilitação.
#
# ### **Desafios Avançados**
# 41. Implemente um jogo de adivinhação onde o programa verifica se o número inserido pelo usuário é maior, menor ou igual ao número secreto.
# 42. Crie um programa que peça uma temperatura e a unidade (Celsius ou Fahrenheit) e converta para a outra unidade.
# 43. Verifique se uma matriz 3x3 é simétrica.
# 44. Crie um programa que peça três números e determine se eles estão em ordem crescente, decrescente ou nenhuma.
# 45. Escreva um programa que calcule o preço final de um produto com base em sua categoria e descontos aplicáveis.
#
# ### **Desafios Adicionais**
# 46. Desenvolva um programa que classifique números em três categorias: `positivos`, `negativos` e `zeros`, armazenando-os em listas diferentes.
# 47. Crie um programa que classifique uma letra como maiúscula, minúscula, número ou símbolo especial.
# 48. Determine se uma data fornecida pelo usuário é válida.
# 49. Faça um programa que peça a hora atual e retorne "Bom dia", "Boa tarde" ou "Boa noite".
# 50. Escreva um programa que analise a pontuação de um jogo e declare o vencedor com base nos critérios fornecidos.
#
# ---
#
# Se precisar de exemplos resolvidos ou explicações detalhadas, é só pedir! 😊
