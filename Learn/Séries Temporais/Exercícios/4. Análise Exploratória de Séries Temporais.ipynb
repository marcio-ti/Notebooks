# %% [markdown]
# ## **📌 Questões - Análise Exploratória de Séries Temporais**
#
# ### **🔹 Básico** (1 a 10)
#
# 1. O que é a decomposição de uma série temporal e qual é a diferença entre decomposição aditiva e multiplicativa?
# 2. Como você pode decompor uma série temporal utilizando o método aditivo com o `seasonal_decompose()` do `statsmodels`?
# 3. O que é a decomposição multiplicativa e quando é mais apropriada do que a decomposição aditiva em séries temporais?
# 4. Como identificar padrões de tendência em uma série temporal? Explique a diferença entre tendência linear e não linear.
# 5. O que são outliers em séries temporais e como você pode detectá-los visualmente usando gráficos de linha?
# 6. Como calcular a média, mediana e desvio padrão de uma série temporal e por que essas estatísticas são úteis na análise exploratória?
# 7. O que é o erro quadrático médio (RMSE) e como ele pode ser útil para avaliar a precisão de um modelo de séries temporais?
# 8. Como você pode usar o gráfico de dispersão para identificar outliers em uma série temporal?
# 9. Como calcular e visualizar a soma dos quadrados dos resíduos para identificar padrões de erro em modelos de séries temporais?
# 10. O que é a normalidade dos resíduos e como você pode testar isso em uma série temporal?
#
# ---
#
# ### **🔹 Intermediário** (11 a 20)
#
# 11. Como a decomposição de uma série temporal pode ajudar a entender melhor a tendência e a sazonalidade dos dados?
# 12. Como usar a função `seasonal_decompose()` do `statsmodels` para realizar a decomposição aditiva de uma série temporal e visualizar seus componentes?
# 13. Quais são as implicações de usar um modelo aditivo em vez de um multiplicativo para decomposição de uma série temporal?
# 14. Como identificar outliers em séries temporais com o método de boxplot e qual é a sua interpretação?
# 15. O que é o autocorrelograma e como ele pode ser utilizado para identificar padrões em séries temporais?
# 16. Explique como a transformação logarítmica pode ajudar na visualização de padrões e na suavização de outliers em séries temporais.
# 17. Como calcular a variância e a covariância de uma série temporal e o que essas estatísticas indicam sobre a série?
# 18. Como você pode analisar a sazonalidade de uma série temporal após a decomposição usando gráficos de linha para cada componente?
# 19. O que são resíduos de uma série temporal e como você pode calculá-los a partir de um modelo ajustado?
# 20. Como a análise de correlação cruzada pode ser usada para identificar padrões entre duas séries temporais?
#
# ---
#
# ### **🔹 Avançado** (21 a 40)
#
# 21. Como calcular e interpretar a correlação de Pearson para avaliar a relação entre duas séries temporais?
# 22. O que é a análise de autocorrelação e como ela pode ser usada para identificar dependências temporais em uma série?
# 23. Explique como a decomposição aditiva de uma série temporal pode ser usada para separar componentes sazonais, tendências e resíduos.
# 24. Quais são os benefícios de normalizar uma série temporal antes de realizar uma decomposição?
# 25. Como identificar mudanças estruturais (rupturas) em uma série temporal usando métodos de análise exploratória?
# 26. Como usar a função `plot_acf()` para examinar a autocorrelação de uma série temporal após a decomposição?
# 27. O que é a análise de heterocedasticidade em séries temporais e como ela pode ser identificada e tratada?
# 28. Como você pode aplicar a análise de séries temporais para detectar ciclos econômicos, como recessões e expansões?
# 29. Como realizar a decomposição de uma série temporal utilizando o `prophet` para identificar tendência e sazonalidade em dados irregulares?
# 30. Explique como a análise de valores faltantes pode ser feita em uma série temporal e como você pode lidar com esses dados ausentes.
# 31. Como usar o `sns.boxplot()` para detectar outliers em séries temporais e o que isso pode indicar sobre os dados?
# 32. Qual é o impacto de outliers na modelagem de séries temporais e como você pode lidar com eles usando transformações?
# 33. Como utilizar a decomposição de séries temporais para visualizar a variação sazonal em um gráfico de linha?
# 34. O que é a análise de componentes principais (PCA) e como ela pode ser aplicada na redução de dimensionalidade de séries temporais multivariadas?
# 35. Como gerar e interpretar uma análise de dispersão (scatter plot) para examinar a relação entre duas séries temporais?
# 36. Como usar o teste de Dickey-Fuller para verificar a estacionariedade de uma série temporal?
# 37. Como aplicar o teste de autocorrelação para validar a presença de padrões temporais não observados diretamente na série temporal?
# 38. Como gerar uma visualização de resíduos a partir de uma decomposição de série temporal e analisar a presença de heterocedasticidade?
# 39. Como interpretar os componentes da decomposição multiplicativa para entender a relação entre a tendência e a sazonalidade de uma série?
# 40. Como você pode usar a decomposição para melhorar a precisão de um modelo ARIMA para previsão de séries temporais?
#
# ---
#
# ## **⚡ Desafios Avançados**
#
# 41. **Decomposição Complexa**: Realize a decomposição de uma série temporal utilizando a decomposição aditiva e multiplicativa, e compare os resultados em termos de precisão para modelar a tendência e a sazonalidade.
# 42. **Detecção de Outliers Avançada**: Aplique técnicas de detecção de outliers em séries temporais utilizando modelos robustos e transforme a série para suavizar os valores discrepantes antes de realizar uma análise mais profunda.
# 43. **Transformação Logarítmica e Normalização**: Aplique uma transformação logarítmica em uma série temporal altamente volátil e analise como isso impacta a decomposição e a identificação de padrões.
# 44. **Identificação de Ciclos Econômicos**: Utilize métodos de análise exploratória para identificar ciclos econômicos (expansões e recessões) em uma série temporal de dados econômicos, como o PIB ou taxa de desemprego.
# 45. **Análise de Tendências Não Lineares**: Aplique a decomposição de séries temporais a uma série com tendência não linear e analise como a decomposição aditiva e multiplicativa afeta a identificação de padrões.
# 46. **Análise de Heterocedasticidade**: Detecte e trate a heterocedasticidade em uma série temporal, utilizando testes e transformações, como a transformação logarítmica ou diferenciação.
# 47. **Previsão de Séries Temporais com Outliers**: Construa um modelo de previsão para uma série temporal com outliers e verifique como a presença de outliers afeta a precisão da previsão.
# 48. **Testes de Estacionariedade**: Realize o teste de Dickey-Fuller em uma série temporal e explique como a estacionariedade pode impactar a modelagem de séries temporais.
# 49. **Análise de Resíduos**: Após a decomposição de uma série temporal, analise os resíduos e aplique testes de heterocedasticidade e normalidade para avaliar o comportamento dos resíduos.
# 50. **PCA em Séries Temporais Multivariadas**: Realize a análise de componentes principais (PCA) em um conjunto de séries temporais multivariadas e explique como isso pode ajudar a reduzir a dimensionalidade e identificar padrões.
#
# ---
#
# Essas questões e desafios cobrem os principais aspectos da **análise exploratória de séries temporais**, como **decomposição**, **identificação de padrões**, **outliers**, e **cálculo de estatísticas descritivas**. 📊✨
#
# Se precisar de mais detalhes ou tiver dúvidas sobre algum exercício, estou à disposição! 😊
