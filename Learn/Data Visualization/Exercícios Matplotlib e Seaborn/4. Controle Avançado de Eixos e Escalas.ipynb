# %% [markdown]
# ## **📌 Exercícios - Controle Avançado de Eixos e Escalas**
#
# ### **🔹 Básico** (1 a 10)
# 1. Plote um gráfico simples e defina os limites do eixo x com `set_xlim()`.
# 2. Defina os limites do eixo y utilizando `set_ylim()`.
# 3. Inverta a direção do eixo x em um gráfico usando `invert_xaxis()`.
# 4. Inverta a direção do eixo y com `invert_yaxis()`.
# 5. Plote um gráfico e ajuste os ticks dos eixos manualmente (`set_xticks()`, `set_yticks()`).
# 6. Modifique os rótulos dos ticks dos eixos com `set_xticklabels()` e `set_yticklabels()`.
# 7. Utilize `grid()` para exibir grades nos eixos e melhore a legibilidade.
# 8. Oculte os eixos de um gráfico (`ax.axis('off')`).
# 9. Ajuste os ticks do eixo x para aparecerem em intervalos personalizados.
# 10. Ajuste os ticks do eixo y para melhor visualização dos dados.
#
# ---
#
# ### **🔹 Intermediário** (11 a 20)
# 11. Plote um gráfico e defina um intervalo fixo para os eixos x e y.
# 12. Use `autoscale()` para redimensionar automaticamente os eixos de um gráfico.
# 13. Plote uma função exponencial e utilize `loglog()` para visualizar melhor os dados.
# 14. Plote um gráfico com escala logarítmica apenas no eixo x (`semilogx()`).
# 15. Plote um gráfico com escala logarítmica apenas no eixo y (`semilogy()`).
# 16. Adicione uma linha de referência nos eixos para indicar um valor específico.
# 17. Crie um gráfico e ajuste os rótulos dos eixos para serem mais legíveis (tamanho e rotação).
# 18. Utilize `MultipleLocator()` para definir um espaçamento fixo entre os ticks.
# 19. Crie um gráfico com escala logarítmica e personalize os ticks para ficarem mais informativos.
# 20. Ajuste os rótulos dos eixos para exibir notação científica.
#
# ---
#
# ### **🔹 Avançado** (21 a 40)
# 21. Plote um gráfico de séries temporais e utilize `mdates.DateFormatter` para formatar os rótulos do eixo x.
# 22. Ajuste automaticamente o espaçamento dos ticks para datas longas com `mdates.AutoDateLocator()`.
# 23. Utilize `mdates.DayLocator()` para exibir apenas dias específicos em um gráfico de datas.
# 24. Plote um gráfico de preços de ações e formate corretamente as datas no eixo x.
# 25. Combine escalas lineares e logarítmicas no mesmo gráfico usando `twiny()` ou `twinx()`.
# 26. Ajuste os limites dos eixos dinamicamente com base em percentis dos dados.
# 27. Personalize os ticks para exibir texto ao invés de números nos eixos.
# 28. Crie um gráfico com dois eixos x (um superior e um inferior) para comparar duas escalas.
# 29. Use `axhline()` e `axvline()` para adicionar linhas de referência no gráfico.
# 30. Ajuste os rótulos do eixo x para evitar sobreposição quando há muitas categorias.
# 31. Plote um gráfico de dispersão e ajuste a escala para destacar valores pequenos.
# 32. Plote um gráfico de densidade e utilize escalas apropriadas para melhor visualização.
# 33. Utilize `LogLocator()` para definir manualmente os ticks em um gráfico logarítmico.
# 34. Plote dados que possuem unidades muito diferentes e normalize os eixos.
# 35. Plote múltiplos gráficos em um layout compartilhando eixos com diferentes escalas.
# 36. Utilize `SecondaryAxis()` para adicionar um eixo secundário a um gráfico.
# 37. Ajuste os rótulos dos ticks para exibir informações adicionais como `%` ou `°C`.
# 38. Plote um gráfico de séries temporais e rotacione os rótulos do eixo x para melhor leitura.
# 39. Crie um gráfico interativo que permita alternar entre escalas logarítmicas e lineares.
# 40. Exporte um gráfico com eixos personalizados garantindo que os rótulos fiquem legíveis.
#
# ---
#
# ## **⚡ Desafios Avançados**
#
# 41. **Comparação de Crescimento Exponencial**: Plote duas séries com diferentes taxas de crescimento e utilize escala logarítmica para análise.
# 42. **Gráfico de Inflação com Escalas Diferentes**: Utilize `twinx()` para exibir a inflação acumulada em um eixo e a variação mensal em outro.
# 43. **Eixos Secundários Dinâmicos**: Plote um gráfico onde um eixo secundário ajusta dinamicamente os valores baseados em uma conversão.
# 44. **Eixo de Tempo Personalizado**: Plote um gráfico de séries temporais e use `mdates` para exibir rótulos dinâmicos conforme o nível de zoom.
# 45. **Análise de Dados Financeiros**: Plote preços de ações em um eixo e o volume negociado em outro, formatando corretamente as datas.
# 46. **Comparação de Modelos Matemáticos**: Plote uma função linear e outra exponencial no mesmo gráfico e ajuste a escala dos eixos para melhor comparação.
# 47. **Personalização Extrema dos Eixos**: Crie um gráfico totalmente estilizado, alterando cores, fontes e espessuras dos eixos.
# 48. **Animação com Escalas Dinâmicas**: Crie uma animação onde os limites dos eixos mudam conforme os dados evoluem.
# 49. **Dashboard de Dados Temporais**: Monte um painel com múltiplos gráficos de séries temporais compartilhando eixos formatados corretamente.
# 50. **Exploração Visual de Dados Científicos**: Plote uma grande quantidade de dados científicos utilizando escalas logarítmicas e secundárias para análise avançada.
#
# ---
#
# Essa lista cobre **do básico ao avançado**, garantindo total domínio sobre controle de eixos e escalas. 🚀📊
#
# Caso queira ajustes ou mais desafios, é só avisar! 😊
