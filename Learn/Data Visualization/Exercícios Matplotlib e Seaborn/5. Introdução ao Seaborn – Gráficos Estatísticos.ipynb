# %% [markdown]
# ## **📌 Exercícios - Introdução ao Seaborn**
#
# ### **🔹 Básico** (1 a 10)
# 1. Importe o Seaborn e carregue o dataset `penguins` para análise.
# 2. Plote um histograma (`histplot()`) da distribuição das massas corporais dos pinguins.
# 3. Use `kdeplot()` para visualizar a distribuição da massa corporal dos pinguins.
# 4. Compare as diferenças entre `histplot()` e `kdeplot()` em um mesmo gráfico.
# 5. Crie um `boxplot()` para visualizar a variação da massa corporal dos pinguins por espécie.
# 6. Use `violinplot()` para exibir a distribuição da massa corporal dos pinguins por espécie.
# 7. Utilize `set_theme()` para aplicar um tema ao Seaborn e refaça um gráfico anterior.
# 8. Modifique o estilo do gráfico utilizando `set_style()`.
# 9. Utilize `set_context()` para criar um gráfico adequado para uma apresentação.
# 10. Compare o mesmo gráfico gerado com Seaborn e Matplotlib e analise a diferença.
#
# ---
#
# ### **🔹 Intermediário** (11 a 20)
# 11. Plote um `histplot()` com diferentes estilos de bins (`auto`, `fd`, `sturges`).
# 12. Use `kdeplot()` para exibir a distribuição de duas variáveis simultaneamente.
# 13. Utilize `boxplot()` para exibir a variação do comprimento da nadadeira (`flipper_length_mm`).
# 14. Adicione jitter ao `boxplot()` utilizando o parâmetro `dodge=True`.
# 15. Plote um `violinplot()` e ajuste `split=True` para comparar distribuições.
# 16. Utilize `stripplot()` sobre um `boxplot()` para visualizar pontos individuais.
# 17. Personalize as cores de um gráfico com a paleta `coolwarm`.
# 18. Modifique a largura da linha em `kdeplot()` usando `linewidth`.
# 19. Plote um `histplot()` com `hue="species"` para visualizar distribuições separadas.
# 20. Utilize `sns.color_palette()` para criar uma paleta de cores personalizada.
#
# ---
#
# ### **🔹 Avançado** (21 a 40)
# 21. Ajuste a transparência de um `violinplot()` para melhorar a visualização dos dados.
# 22. Plote um `kdeplot()` com preenchimento ativado (`shade=True`).
# 23. Personalize os rótulos do eixo e título do gráfico com `set_xlabel()`, `set_ylabel()`, `set_title()`.
# 24. Crie um `boxplot()` e altere a largura dos boxes.
# 25. Ajuste o tamanho de um gráfico com `figsize` e use `dpi` para maior resolução.
# 26. Use `despine()` para remover a moldura superior e direita de um gráfico.
# 27. Plote um `histplot()` e altere a opacidade com `alpha`.
# 28. Modifique a escala do eixo y para logarítmica em um gráfico de distribuição.
# 29. Use `sns.set_palette()` para definir uma paleta padrão para todos os gráficos.
# 30. Adicione rótulos de valor aos pontos de um gráfico de dispersão (`scatterplot()`).
# 31. Plote um `violinplot()` e ajuste a largura das violas para diferentes categorias.
# 32. Compare gráficos com diferentes estilos (`darkgrid`, `whitegrid`, `ticks`).
# 33. Use `hue="species"` para separar as distribuições de pinguins em um `boxplot()`.
# 34. Ajuste a largura das colunas em um `histplot()`.
# 35. Adicione uma legenda personalizada a um gráfico do Seaborn.
# 36. Utilize `set_context("talk")` para criar um gráfico otimizado para apresentações.
# 37. Salve um gráfico gerado pelo Seaborn em formato PNG e PDF.
# 38. Plote um gráfico estatístico com `FacetGrid()`.
# 39. Ajuste manualmente os ticks do eixo x e y para melhorar a visualização.
# 40. Gere um gráfico estatístico e exporte-o com um fundo transparente.
#
# ---
#
# ## **⚡ Desafios Avançados**
#
# 41. **Comparação de Distribuições**: Plote um `histplot()` e um `kdeplot()` no mesmo gráfico, personalizando cores e estilos.
# 42. **Análise de Outliers**: Utilize `boxplot()` e `violinplot()` para detectar outliers em um dataset real.
# 43. **Exploração de Dados Financeiros**: Plote um gráfico estatístico sobre um dataset de preços de ações.
# 44. **Visualização de Tendências**: Use `histplot()` para analisar a distribuição de preços de imóveis em um dataset real.
# 45. **Customização Extrema**: Crie um gráfico altamente estilizado combinando vários métodos do Seaborn.
# 46. **Gráficos Temáticos**: Escolha um tema (`set_style()`) e crie uma série de gráficos com ele.
# 47. **Efeitos de Paleta de Cores**: Compare o impacto de diferentes paletas (`viridis`, `coolwarm`, `magma`) em gráficos estatísticos.
# 48. **Dashboard Estatístico**: Monte um painel de visualização combinando pelo menos 3 tipos de gráficos estatísticos.
# 49. **Comparação de Modelos**: Utilize gráficos do Seaborn para visualizar a performance de modelos de Machine Learning.
# 50. **Storytelling com Dados**: Crie uma visualização narrativa utilizando gráficos estatísticos para contar uma história com os dados.
#
# ---
#
# Essa lista cobre **do básico ao avançado**, garantindo total domínio sobre **gráficos estatísticos no Seaborn**. 🚀📊
#
# Caso queira ajustes ou mais desafios, é só avisar! 😊
