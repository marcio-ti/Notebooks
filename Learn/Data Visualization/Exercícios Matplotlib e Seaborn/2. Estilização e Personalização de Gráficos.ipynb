# %% [markdown]
# ## **📌 Exercícios - Estilização e Personalização de Gráficos**
#
# ### **🔹 Básico** (1 a 10)
# 1. Plote um gráfico de linha simples e altere a cor da linha para azul.
# 2. Modifique a espessura da linha para 2.5 pixels em um gráfico de linha.
# 3. Plote um gráfico de dispersão e utilize marcadores triangulares (`^`).
# 4. Altere o estilo da linha para tracejado (`--`) e a cor para verde.
# 5. Crie um gráfico de barras e modifique a cor das barras para um tom personalizado de vermelho.
# 6. Personalize um gráfico de pizza alterando manualmente as cores das fatias.
# 7. Adicione uma legenda a um gráfico e posicione-a no canto superior direito.
# 8. Aplique um grid ao gráfico e ajuste a opacidade para 0.5 (`alpha`).
# 9. Modifique os limites dos eixos x e y para um intervalo específico.
# 10. Utilize um colormap (`plasma`) para colorir os pontos de um gráfico de dispersão.
#
# ---
#
# ### **🔹 Intermediário** (11 a 20)
# 11. Ajuste o tamanho da fonte dos rótulos dos eixos x e y para 14.
# 12. Use `rcParams` para definir um tamanho de fonte padrão para todos os gráficos.
# 13. Plote um gráfico de barras e personalize a largura das barras para 0.4.
# 14. Ajuste o espaçamento entre legendas para evitar sobreposição.
# 15. Personalize um gráfico de dispersão aplicando cores baseadas em valores (`cmap`).
# 16. Modifique a espessura das linhas do grid para 1.2 pixels.
# 17. Adicione um título ao gráfico, centralizando e aumentando o tamanho da fonte.
# 18. Ajuste a transparência (`alpha`) de uma linha para 0.6.
# 19. Personalize a orientação dos rótulos do eixo x para 45 graus.
# 20. Remova a borda superior e direita de um gráfico para um design mais limpo.
#
# ---
#
# ### **🔹 Avançado** (21 a 40)
# 21. Crie um gráfico com múltiplas séries de dados, cada uma com um estilo de linha diferente.
# 22. Aplique um tema de gráfico global usando `plt.style.use('seaborn-darkgrid')`.
# 23. Plote um gráfico de dispersão e adicione rótulos individuais para cada ponto.
# 24. Ajuste manualmente a posição da legenda usando coordenadas `(x, y)`.
# 25. Personalize um gráfico de pizza adicionando sombras e destacando uma fatia (`explode`).
# 26. Estilize um gráfico de áreas ajustando a transparência e as cores das áreas.
# 27. Crie um gráfico de colunas agrupadas e diferencie os grupos por cor e espaçamento.
# 28. Plote um gráfico com dois eixos y diferentes e aplique estilos distintos a cada um.
# 29. Modifique o estilo das setas em um gráfico de vetores (`quiver`).
# 30. Plote um gráfico de linha com eixos logarítmicos e personalize os ticks.
# 31. Adicione anotações (`annotate`) a um gráfico para destacar pontos específicos.
# 32. Aplique um fundo personalizado em um gráfico, como um degradê de cores.
# 33. Ajuste o espaçamento entre múltiplos gráficos (`subplots_adjust`) para evitar sobreposição.
# 34. Crie um gráfico de densidade (`hexbin`) e personalize a colormap e os bins.
# 35. Utilize `rcParams` para alterar globalmente a cor de fundo dos gráficos.
# 36. Plote um gráfico de caixa e ajuste a largura das linhas e a cor dos outliers.
# 37. Personalize um gráfico de barras utilizando padrões (`hatch`) nas colunas.
# 38. Plote um heatmap personalizado e adicione uma barra de cores (`colorbar`).
# 39. Combine múltiplos gráficos (linha, barras e dispersão) na mesma figura com diferentes estilos.
# 40. Crie um gráfico estilizado pronto para um relatório profissional, aplicando boas práticas de design.
#
# ---
#
# ## **⚡ Desafios Avançados**
#
# 41. **Gráfico com Imagem de Fundo**: Insira uma imagem de fundo no gráfico e ajuste sua transparência para manter a legibilidade.
# 42. **Animação de Linha Crescente**: Crie uma animação onde uma linha cresce ao longo do tempo.
# 43. **Dashboard Simples com Matplotlib**: Combine múltiplos gráficos estilizados em uma única figura organizada para simular um mini-dashboard.
# 44. **Tema Customizado com `rcParams`**: Defina um conjunto de estilos personalizados e aplique-os a todos os gráficos de um projeto.
# 45. **Gráfico Estilizado para Apresentação**: Desenvolva um gráfico profissional, pronto para ser inserido em um slide ou relatório.
# 46. **Gráfico com Destaques Dinâmicos**: Plote uma série temporal e destaque dinamicamente os picos e vales da série alterando cores e marcadores.
# 47. **Estilização Avançada de Subgráficos**: Crie 4 subgráficos, cada um com um estilo único, incluindo grid, cores e legendas.
# 48. **Radar Chart Personalizado**: Plote um gráfico de radar e estilize-o para melhorar a legibilidade e o impacto visual.
# 49. **Interação com `mplcursors`**: Permita que o usuário passe o mouse sobre pontos de um gráfico de dispersão para visualizar detalhes.
# 50. **Gráfico 3D Customizado**: Plote um gráfico de superfície 3D e personalize iluminação, colormap e ângulo de visualização.
#
# ---
#
# Essa lista cobre desde o **básico até o avançado**, garantindo uma evolução progressiva no aprendizado da estilização de gráficos. 🎨📊
#
# Gostaria de adicionar algo mais ou ajustar algum detalhe? 😊
