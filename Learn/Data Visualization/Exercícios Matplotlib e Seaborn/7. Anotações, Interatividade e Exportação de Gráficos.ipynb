# %% [markdown]
# ## **📌 Exercícios - Anotações, Interatividade e Exportação de Gráficos**
#
# ### **🔹 Básico** (1 a 10)
# 1. Crie um gráfico de linha simples usando `plot()`.
# 2. Adicione uma legenda ao gráfico com `legend()`.
# 3. Use `text()` para adicionar um rótulo em um ponto específico do gráfico.
# 4. Utilize `annotate()` para destacar um valor máximo no gráfico.
# 5. Ajuste a posição da legenda com `loc="upper left"`.
# 6. Adicione uma seta ao `annotate()` para apontar para um valor importante.
# 7. Mude a fonte e o tamanho do texto da anotação.
# 8. Plote um gráfico de dispersão e adicione títulos nos eixos com `xlabel()` e `ylabel()`.
# 9. Modifique a opacidade da anotação utilizando `alpha=0.5`.
# 10. Use `bbox` no `annotate()` para destacar o fundo do texto anotado.
#
# ---
#
# ### **🔹 Intermediário** (11 a 20)
# 11. Crie um gráfico com duas linhas e adicione uma legenda personalizada.
# 12. Use `mplcursors` para permitir a exibição dos valores ao passar o mouse.
# 13. Modifique o estilo da linha e da seta no `annotate()`.
# 14. Plote um gráfico de barras e adicione rótulos nos topos das barras.
# 15. Ajuste a transparência (`alpha`) dos rótulos no gráfico de barras.
# 16. Altere o alinhamento do texto no `annotate()`.
# 17. Use `zorder` para garantir que a anotação apareça acima dos dados do gráfico.
# 18. Teste diferentes estilos de legendas com `frameon=True` e `fancybox=True`.
# 19. Plote um gráfico de dispersão e use `mplcursors` para exibir informações ao passar o mouse.
# 20. Adicione uma anotação dinâmica que destaque o valor médio de um conjunto de dados.
#
# ---
#
# ### **🔹 Avançado** (21 a 40)
# 21. Plote um gráfico de linhas e anote os pontos de pico automaticamente.
# 22. Modifique a cor do fundo da anotação utilizando `bbox=dict(facecolor="yellow")`.
# 23. Salve um gráfico em alta resolução usando `savefig(dpi=300)`.
# 24. Exporte um gráfico para PDF e PNG utilizando `savefig()`.
# 25. Remova os espaços em branco ao redor do gráfico salvo (`bbox_inches="tight"`).
# 26. Plote um histograma e use `text()` para adicionar rótulos nas barras.
# 27. Teste diferentes posições da legenda (`loc="best"`).
# 28. Utilize `mplcursors` para exibir múltiplas informações ao passar o mouse.
# 29. Plote um gráfico de pizza e adicione rótulos personalizados aos setores.
# 30. Ajuste o espaçamento entre os rótulos de um gráfico de pizza.
# 31. Plote um gráfico de dispersão e exiba as coordenadas ao clicar em um ponto.
# 32. Crie um gráfico de área e adicione uma legenda explicativa.
# 33. Teste diferentes estilos de fontes nos rótulos de um gráfico.
# 34. Ajuste a espessura da borda da legenda com `edgecolor`.
# 35. Combine diferentes estilos de anotações em um mesmo gráfico.
# 36. Crie um gráfico com múltiplas subfiguras e anote um ponto em cada subplot.
# 37. Teste diferentes formatos de exportação (`jpg`, `pdf`, `svg`).
# 38. Exporte um gráfico interativo utilizando `mplcursors` e verifique a diferença no comportamento.
# 39. Plote um gráfico de radar e adicione rótulos nos pontos-chave.
# 40. Salve um gráfico com fundo transparente (`transparent=True`).
#
# ---
#
# ## **⚡ Desafios Avançados**
# 41. **Anotação Dinâmica**: Crie um gráfico onde as anotações mudam de posição conforme o zoom.
# 42. **Gráfico Interativo**: Desenvolva um gráfico com `mplcursors` que exibe informações detalhadas ao passar o mouse.
# 43. **Relatório em PDF**: Exporte um conjunto de gráficos para um único arquivo PDF.
# 44. **Legendas Inteligentes**: Crie um gráfico onde a posição da legenda muda automaticamente dependendo dos valores dos dados.
# 45. **Destaque de Áreas**: Utilize `fill_between()` para destacar uma região específica do gráfico e adicione uma anotação explicativa.
# 46. **Anotação Automática**: Escreva um código que anote automaticamente os picos e vales de uma curva.
# 47. **Exportação Otimizada**: Salve um gráfico em três formatos diferentes, ajustando as configurações para cada um.
# 48. **Interação Avançada**: Crie um gráfico onde um clique exibe um rótulo personalizado sobre o ponto selecionado.
# 49. **Anotações com Dados em Tempo Real**: Plote um gráfico que atualiza as anotações dinamicamente conforme novos dados são adicionados.
# 50. **Dashboard Simples**: Combine múltiplos gráficos anotados e interativos em uma única figura, simulando um painel de análise.
#
# ---
#
# Essa lista cobre **todos os aspectos de Anotações, Interatividade e Exportação de Gráficos**, garantindo domínio sobre **annotate(), mplcursors e savefig()**. 🚀📊
#
# Se precisar de ajustes ou mais desafios, só avisar! 😊
