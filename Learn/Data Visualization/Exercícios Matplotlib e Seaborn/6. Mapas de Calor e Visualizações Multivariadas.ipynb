# %% [raw]
# ## **📌 Exercícios - Mapas de Calor e Visualizações Multivariadas**
#
# ### **🔹 Básico** (1 a 10)
# 1. Importe o Seaborn e carregue o dataset `penguins` para análise.
# 2. Gere uma matriz de correlação (`corr()`) a partir do dataset `penguins`.
# 3. Utilize `heatmap()` para visualizar a matriz de correlação.
# 4. Adicione rótulos aos valores do `heatmap()` com `annot=True`.
# 5. Ajuste a paleta de cores do `heatmap()` utilizando `cmap="coolwarm"`.
# 6. Modifique a escala do `heatmap()` ajustando `vmin` e `vmax`.
# 7. Plote um `pairplot()` com o dataset `penguins` para visualizar as relações entre variáveis.
# 8. Utilize `hue="species"` no `pairplot()` para destacar categorias diferentes.
# 9. Remova a regressão do `pairplot()` desativando `kind="reg"`.
# 10. Plote um `FacetGrid` com os pinguins separados por espécie.
#
# ---
#
# ### **🔹 Intermediário** (11 a 20)
# 11. Personalize um `heatmap()` alterando os valores de opacidade (`alpha`).
# 12. Ajuste o tamanho das anotações em um `heatmap()` utilizando `fmt=".2f"`.
# 13. Utilize `mask` para esconder a diagonal superior de um `heatmap()`.
# 14. Gere um `pairplot()` exibindo apenas variáveis numéricas do dataset.
# 15. Ajuste o tamanho dos gráficos no `pairplot()` com `height=2.5`.
# 16. Use `diag_kind="kde"` no `pairplot()` para exibir distribuições suaves na diagonal.
# 17. Plote um `FacetGrid()` de histogramas para cada espécie de pinguim.
# 18. Modifique os estilos do `FacetGrid()` utilizando `set_titles()`.
# 19. Compartilhe eixos entre subplots no `FacetGrid()` com `sharex=True` e `sharey=True`.
# 20. Ajuste o espaçamento do `FacetGrid()` utilizando `despine()`.
#
# ---
#
# ### **🔹 Avançado** (21 a 40)
# 21. Remova ticks dos eixos no `heatmap()` para um visual mais limpo.
# 22. Plote um `heatmap()` usando uma paleta de cores personalizada.
# 23. Ajuste a posição do `colorbar` no `heatmap()`.
# 24. Adicione linhas divisórias no `heatmap()` com `linewidths=0.5`.
# 25. Gere um `pairplot()` excluindo variáveis categóricas do dataset.
# 26. Ajuste o `hue_order` no `pairplot()` para mudar a ordem das categorias.
# 27. Adicione uma linha de tendência aos gráficos do `pairplot()` utilizando `kind="reg"`.
# 28. Plote um `FacetGrid()` de `scatterplots` colorindo por espécie.
# 29. Personalize os títulos de cada subplot do `FacetGrid()`.
# 30. Exiba apenas variáveis selecionadas no `pairplot()` utilizando `vars=["bill_length_mm", "bill_depth_mm"]`.
# 31. Adicione diferentes tamanhos de pontos no `pairplot()` usando `markers=["o", "s", "D"]`.
# 32. Remova a diagonal do `pairplot()` utilizando `diag_kind=None`.
# 33. Ajuste a escala de um `heatmap()` para evidenciar diferenças sutis nos dados.
# 34. Plote um `FacetGrid()` de `kdeplot()` para cada espécie de pinguim.
# 35. Ajuste a transparência dos gráficos no `FacetGrid()`.
# 36. Utilize uma métrica diferente de correlação (`spearman` ou `kendall`) no `heatmap()`.
# 37. Gere um `pairplot()` com `corner=True` para exibir apenas a metade inferior.
# 38. Utilize `refline()` no `FacetGrid()` para adicionar uma linha de referência.
# 39. Ajuste a resolução e qualidade de um gráfico salvo utilizando `dpi=300`.
# 40. Salve um `heatmap()` com fundo transparente e em alta resolução.
#
# ---
#
# ## **⚡ Desafios Avançados**
# 41. **Heatmap com Dados Faltantes**: Crie um `heatmap()` para visualizar valores ausentes (`NaN`) em um dataset.
# 42. **Analisando Correlações de Mercado Financeiro**: Utilize um dataset financeiro e plote um `heatmap()` com as correlações entre ativos.
# 43. **Exploração de um Dataset Climático**: Utilize `FacetGrid()` para visualizar padrões climáticos ao longo do tempo.
# 44. **Heatmap Interativo**: Exporte um `heatmap()` para um formato interativo utilizando Plotly.
# 45. **Exploração de Vendas de um E-commerce**: Utilize `pairplot()` para analisar padrões de compras em um dataset de vendas.
# 46. **Analisando Tendências de Esportes**: Plote um `FacetGrid()` para visualizar estatísticas de jogadores de futebol ou basquete.
# 47. **Criando uma Matriz de Confusão**: Gere um `heatmap()` para visualizar a matriz de confusão de um modelo de Machine Learning.
# 48. **Comparação de Correlações**: Plote dois `heatmap()` lado a lado comparando diferentes métodos de correlação.
# 49. **Faceta de Múltiplos Gráficos Avançados**: Utilize `FacetGrid()` para combinar `scatterplot()` e `kdeplot()` em uma única visualização.
# 50. **História Contada com Dados**: Crie uma narrativa visual utilizando `heatmap()`, `pairplot()` e `FacetGrid()` para contar uma história baseada nos dados.
#
# ---
#
# Essa lista cobre **todos os aspectos de Mapas de Calor e Visualizações Multivariadas**, garantindo total domínio sobre **heatmaps, pairplots e FacetGrid**. 🚀🔥📊
#
# Se quiser ajustes ou mais desafios, só avisar! 😊
