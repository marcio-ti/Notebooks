# %% [markdown]
# ## **📌 Exercícios - Layouts e Múltiplos Gráficos**
#
# ### **🔹 Básico** (1 a 10)
# 1. Crie dois gráficos lado a lado usando `subplot()`.
# 2. Plote um gráfico de linha e um de dispersão em uma figura com `subplots()`.
# 3. Ajuste o espaçamento entre os gráficos utilizando `tight_layout()`.
# 4. Modifique o tamanho da figura ao criar múltiplos gráficos (`figsize`).
# 5. Plote quatro gráficos (2x2) e personalize cada um com títulos diferentes.
# 6. Utilize `constrained_layout()` para evitar sobreposição entre gráficos.
# 7. Compartilhe o eixo x entre dois gráficos (`sharex=True`).
# 8. Compartilhe o eixo y entre três gráficos (`sharey=True`).
# 9. Ajuste a posição dos rótulos dos eixos para evitar sobreposição.
# 10. Remova os rótulos dos eixos de um dos subgráficos para melhorar o design.
#
# ---
#
# ### **🔹 Intermediário** (11 a 20)
# 11. Crie uma grade 3x2 e distribua gráficos de diferentes tipos.
# 12. Adicione uma legenda única para todos os gráficos de uma figura.
# 13. Plote três gráficos e ajuste o tamanho de cada um individualmente.
# 14. Aplique cores diferentes para o fundo de cada subplot.
# 15. Remova os eixos de um dos subgráficos para criar um efeito limpo.
# 16. Ajuste manualmente o espaçamento entre subgráficos (`subplots_adjust`).
# 17. Adicione anotações em um subplot sem interferir nos demais.
# 18. Alinhe gráficos verticalmente e compartilhe eixos x e y.
# 19. Plote gráficos de barras e ajuste a largura para melhorar a legibilidade.
# 20. Estilize os títulos de cada subplot usando fontes e tamanhos personalizados.
#
# ---
#
# ### **🔹 Avançado** (21 a 40)
# 21. Combine diferentes tipos de gráficos em um layout 2x2 (linha, barras, dispersão, pizza).
# 22. Adicione um título geral (`suptitle()`) para descrever a figura completa.
# 23. Utilize `gridspec` para criar subgráficos de tamanhos desiguais.
# 24. Adicione linhas de grade personalizadas a cada subplot.
# 25. Crie um gráfico com 5 subplots onde um ocupa duas colunas.
# 26. Adicione uma barra de cores (`colorbar`) compartilhada entre gráficos de dispersão.
# 27. Plote um gráfico de calor (`heatmap`) em um layout com múltiplos gráficos.
# 28. Personalize as bordas dos gráficos para criar um efeito visual mais atraente.
# 29. Utilize `twiny()` para criar dois gráficos sobrepostos com diferentes escalas no eixo x.
# 30. Combine múltiplos gráficos em uma única visualização utilizando `plt.subplot_mosaic()`.
# 31. Ajuste manualmente os limites de cada subplot (`set_xlim`, `set_ylim`).
# 32. Crie um layout de subplots que se adapte automaticamente ao tamanho da figura.
# 33. Adicione setas e anotações para conectar informações entre diferentes gráficos.
# 34. Plote múltiplos gráficos 3D em uma figura usando `subplot()`.
# 35. Utilize um loop para automatizar a criação de múltiplos subplots.
# 36. Aplique um estilo global (`plt.style.use()`) a todos os subgráficos.
# 37. Modifique dinamicamente o número de subplots baseado em uma variável.
# 38. Combine gráficos com diferentes escalas no mesmo layout.
# 39. Crie um layout de gráficos que se reorganiza automaticamente ao redimensionar a janela.
# 40. Exporte um layout complexo como imagem (`savefig()`) sem perder qualidade.
#
# ---
#
# ## **⚡ Desafios Avançados**
#
# 41. **Dashboard Multi-Gráficos**: Crie um painel com 6 gráficos inter-relacionados e bem organizados.
# 42. **Gráfico com Layout Personalizado**: Use `gridspec` para criar um layout complexo e balanceado.
# 43. **Múltiplos Gráficos em Tempo Real**: Atualize múltiplos subplots dinamicamente usando `FuncAnimation`.
# 44. **Comparação de Dados em Dois Painéis**: Crie duas colunas de gráficos para comparar duas fontes de dados diferentes.
# 45. **Mosaico de Gráficos**: Organize gráficos de diferentes tamanhos e formatos com `subplot_mosaic()`.
# 46. **Exploração de Dados com Subplots**: Crie um conjunto de gráficos exploratórios para análise de dados.
# 47. **Interatividade com `mplcursors`**: Adicione interação nos subplots para exibir informações ao passar o mouse.
# 48. **Painel para Relatórios**: Desenvolva uma visualização refinada pronta para um relatório profissional.
# 49. **Layout Dinâmico com Widgets**: Crie múltiplos gráficos em um layout interativo com `ipywidgets`.
# 50. **Animação com Múltiplos Subplots**: Desenvolva uma animação sincronizada em diferentes gráficos.
#
# ---
#
# Essa lista cobre desde o **básico até o avançado**, garantindo domínio sobre layouts e múltiplos gráficos. 🚀📊
#
# Precisa de ajustes ou quer mais desafios? 😊
