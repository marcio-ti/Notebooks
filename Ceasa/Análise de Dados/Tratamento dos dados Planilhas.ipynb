# %%
import pandas as pd
import plotly.graph_objects as go
import warnings
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime
import numpy as np
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:.3f}'.format

# %% [markdown]
# ## Atacadistas
# <hr>

# %%
# Carregando os dados
atacadista = pd.read_excel(r"C:\Users\divtec-dados\OneDrive\CEASA\Anchieta\Relatórios\Atacadistas Bruto.xlsx", sheet_name='Lançamentos - Atacadistas')
atacadista['DATA'] = pd.to_datetime(atacadista['DATA'], format='%d/%m/%Y', dayfirst=True)
atacadista = atacadista[['DATA','ATACADISTA','PRODUTO','VOLUME']]

# Criando a coluna de dias da semana e renomeando para texto
atacadista['DIA DA SEMANA'] = atacadista['DATA'].dt.dayofweek
dias_da_semana_nomes = {0:"Segunda-feira", 1:"Terça-feira",2:"Quarta-feira",3:"Quinta-feira",4:"Sexta-feira",5:"Sábado",6:"Domingo"}
atacadista['DIA DA SEMANA'] = atacadista['DIA DA SEMANA'].map(dias_da_semana_nomes)

# Criando a Coluna para especificar o mês a que a data está relacionada
atacadista['MES'] = atacadista['DATA'].dt.month
meses_do_ano_nomes = {1:"Jan", 2:"Fev",3:"Mar",4:"Abr",5:"Mai",6:"Jun",7:"Jul",8:"Ago",9:"Set",10:"Out",11:"Nov",12:"Dez"}
atacadista["MES"] = atacadista["MES"].map(meses_do_ano_nomes)

# %%
atacadista
# Out:
#             DATA                        ATACADISTA  \
# 0     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# 1     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# 2     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# 3     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# 4     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# ...          ...                               ...
# 14086 2024-07-23   5501008-COMERCIO DE FRUTAS METZ
# 14087 2024-07-23  5500089-L.B. COMERCIO DE CEREAIS
# 14088 2024-07-23   5501005-FORTESUL IMP. DE FRUTAS
# 14089 2024-07-23  5501033-COMERCIO DE CEREAIS BELE
# 14090 2024-07-23  5500876-COMERCIAL AGRICOLA DE GR
#
#                                   PRODUTO    VOLUME  DIA DA SEMANA  MES
# 0                     05601-REPOLHO VERDE   370.224  Segunda-feira  Jun
# 1                06003-ABOBRINHA ITALIANA   435.000  Segunda-feira  Jun
# 2                         06101-BERINJELA   400.000  Segunda-feira  Jun
# 3                            06201-CHUCHU  1400.000  Segunda-feira  Jun
# 4                     07002-PEPINO SALADA  1300.000  Segunda-feira  Jun
# ...                                   ...       ...            ...  ...
# 14086                 01802-MAMAO FORMOSA 22650.000    Terça-feira  Jul
# 14087               08001-CEBOLA NACIONAL 23000.000    Terça-feira  Jul
# 14088       02755-PERA WILLIAMS / PACKAMS 23184.000    Terça-feira  Jul
# 14089                07701-BATATA INGLESA 32000.000    Terça-feira  Jul
# 14090  07405-TOMATE CEREJA (MINI TOMATES) 37115.000    Terça-feira  Jul
#
# [14091 rows x 6 columns]

# %% [markdown]
# ## Produtores
# <hr>

# %%
produtores = pd.read_excel(r"C:\Users\divtec-dados\OneDrive\CEASA\Anchieta\Relatórios\Produtores Bruto.xlsx", sheet_name='Lançamentos-Produtores')
produtores['DATA'] = pd.to_datetime(produtores['DATA'], format='%d/%m/%Y', dayfirst=True)
produtores = produtores[['DATA','PRODUTOR','PRODUTO','VOLUME']]

# Criando a coluna de dias da semana e renomeando para texto
produtores['DIA DA SEMANA'] = produtores['DATA'].dt.dayofweek
dias_da_semana_nomes = {0:"Segunda-feira", 1:"Terça-feira",2:"Quarta-feira",3:"Quinta-feira",4:"Sexta-feira",5:"Sábado",6:"Domingo"}
produtores['DIA DA SEMANA'] = produtores['DIA DA SEMANA'].map(dias_da_semana_nomes)

# Criando a Coluna para especificar o mês a que a data está relacionada
produtores['MES'] = produtores['DATA'].dt.month
meses_do_ano_nomes = {1:"Jan", 2:"Fev",3:"Mar",4:"Abr",5:"Mai",6:"Jun",7:"Jul",8:"Ago",9:"Set",10:"Out",11:"Nov",12:"Dez"}
produtores["MES"] = produtores["MES"].map(meses_do_ano_nomes)

# %%
produtores
# Out:
#             DATA                          PRODUTOR  \
# 0     2024-06-17            0102763-KINZABURO SATO
# 1     2024-06-17       0102643-YOSHIYUKI TAKAHASHI
# 2     2024-06-17       0106013-KATSUYOSHI YAMAZAKI
# 3     2024-06-17       0106013-KATSUYOSHI YAMAZAKI
# 4     2024-06-17      0106039-CARLOS ANTONIO GILLI
# ...          ...                               ...
# 19209 2024-07-23    0102217-SIDNEI GROHLER GALGARO
# 19210 2024-07-23       0115494-FLAVIA DADALT NEVES
# 19211 2024-07-23  0102547-IVANETE MALACARNE STUANI
# 19212 2024-07-23   0101024-MARCELO LUIS HINTERHOLZ
# 19213 2024-07-23           0109922-AMARO JOSE RECH
#
#                             PRODUTO    VOLUME  DIA DA SEMANA  MES
# 0      04801-CHEIRO VERDE / TEMPERO     1.000  Segunda-feira  Jun
# 1                  05402-MANJERICAO     1.250  Segunda-feira  Jun
# 2                   05401-MANJERONA     2.400  Segunda-feira  Jun
# 3                  05402-MANJERICAO     2.500  Segunda-feira  Jun
# 4            05102-ERVAS AROMATICAS     3.600  Segunda-feira  Jun
# ...                             ...       ...            ...  ...
# 19209                 08102-CENOURA  5000.000    Terça-feira  Jul
# 19210             10101-BATATA-DOCE  5100.000    Terça-feira  Jul
# 19211                 08102-CENOURA  6000.000    Terça-feira  Jul
# 19212                08501-MANDIOCA 10000.000    Terça-feira  Jul
# 19213  03204-TANGERINA MONTENEGRINA 10440.000    Terça-feira  Jul
#
# [19214 rows x 6 columns]

# %% [markdown]
# ## Merge DATAFRAMES Produtores e Atacadistas
# <hr>

# %%
df1 = atacadista.copy(deep=True)
df2 = produtores.copy(deep=True)
df1['TIPO'] = "ATACADISTA"
df2['TIPO'] = "PRODUTOR"

# %%
df1.rename(columns={"ATACADISTA":'NOME'}, inplace=True)
df2.rename(columns={"PRODUTOR":'NOME'}, inplace=True)
merged_volumes = pd.concat([df1, df2], ignore_index=True)

# %%
merged_volumes
# Out:
#             DATA                              NOME  \
# 0     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# 1     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# 2     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# 3     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# 4     2024-06-17  5500020-BRAULIO COMERCIAL DE FR.
# ...          ...                               ...
# 33300 2024-07-23    0102217-SIDNEI GROHLER GALGARO
# 33301 2024-07-23       0115494-FLAVIA DADALT NEVES
# 33302 2024-07-23  0102547-IVANETE MALACARNE STUANI
# 33303 2024-07-23   0101024-MARCELO LUIS HINTERHOLZ
# 33304 2024-07-23           0109922-AMARO JOSE RECH
#
#                             PRODUTO    VOLUME  DIA DA SEMANA  MES        TIPO
# 0               05601-REPOLHO VERDE   370.224  Segunda-feira  Jun  ATACADISTA
# 1          06003-ABOBRINHA ITALIANA   435.000  Segunda-feira  Jun  ATACADISTA
# 2                   06101-BERINJELA   400.000  Segunda-feira  Jun  ATACADISTA
# 3                      06201-CHUCHU  1400.000  Segunda-feira  Jun  ATACADISTA
# 4               07002-PEPINO SALADA  1300.000  Segunda-feira  Jun  ATACADISTA
# ...                             ...       ...            ...  ...         ...
# 33300                 08102-CENOURA  5000.000    Terça-feira  Jul    PRODUTOR
# 33301             10101-BATATA-DOCE  5100.000    Terça-feira  Jul    PRODUTOR
# 33302                 08102-CENOURA  6000.000    Terça-feira  Jul    PRODUTOR
# 33303                08501-MANDIOCA 10000.000    Terça-feira  Jul    PRODUTOR
# 33304  03204-TANGERINA MONTENEGRINA 10440.000    Terça-feira  Jul    PRODUTOR
#
# [33305 rows x 7 columns]

# %%
merged_volumes.to_parquet("Dados Comercializacao.parquet")

# %%
merged_volumes2 = merged_volumes.groupby(['DATA','TIPO'])["VOLUME"].sum()

# %%
merged_volumes2.to_excel(r"C:\Users\divtec-dados\OneDrive\CEASA\Anchieta\Relatórios\Totais.xlsx")

# %% [markdown]
# ## Cotações
# <hr>

# %%
cotacoes = pd.read_excel(r"C:\Users\divtec-dados\OneDrive\CEASA\Anchieta\Cotação\Cotações.xlsx", sheet_name="Cotação")
# cotacoes['DATA'] = pd.to_datetime(cotacoes['DATA']).dt.strftime('%d-%b-%y')
# # Mapeamento dos meses em inglês para português
# meses = {
#     'Jan': 'Jan',
#     'Feb': 'Fev',
#     'Mar': 'Mar',
#     'Apr': 'Abr',
#     'May': 'Mai',
#     'Jun': 'Jun',
#     'Jul': 'Jul',
#     'Aug': 'Ago',
#     'Sep': 'Set',
#     'Oct': 'Out',
#     'Nov': 'Nov',
#     'Dec': 'Dez'
# }
# 
# # Aplica a substituição na coluna 'DATA'
# cotacoes['DATA'] = cotacoes['DATA'].replace(meses, regex=True)
cotacoes
# Out:
#             DATA                       PRODUTO UNIDADE  MÁXIMO  \
# 0     2024-04-18                 00101-ABACATE      KG    6.00
# 1     2024-04-18  00201-ABACAXI CAIENA (HAWAI)     UND    8.50
# 2     2024-04-18          00202-ABACAXI PEROLA     UND    8.50
# 3     2024-04-18  00203-ABACAXI TERRA DE AREIA     UND    4.00
# 4     2024-04-18                 05901-ABOBORA      KG    6.00
# ...          ...                           ...     ...     ...
# 11225 2024-07-18       53104-VERDES EUCALIPTUS     MOL   35.00
# 11226 2024-07-18           53204-VERDES RUSCUS     MOL   25.00
# 11227 2024-07-18                 51801-VIOLETA     UND    8.00
# 11228 2024-07-18                   12201-YACON      KG   15.00
# 11229 2024-07-18                    ZAMIOCULCA     UND   40.00
#
#        MAIS FREQUENTE  MINIMO
# 0                3.89    2.50
# 1                8.00    6.00
# 2                8.00    5.00
# 3                3.50    2.00
# 4                4.00    3.50
# ...               ...     ...
# 11225           30.00   30.00
# 11226           24.00   23.00
# 11227            8.00    6.00
# 11228            8.67    7.22
# 11229           35.00   30.00
#
# [11230 rows x 6 columns]

# %% [markdown]
# Gráficos Cotação

# %% [markdown]
# ## Contagem de Atacadistas e Produtores
# <hr>

# %%
data = "2024-07-23"
n_atacadistas = atacadista.copy(deep=True)
n_produtores = produtores.copy(deep=True)

n_atacadistas = n_atacadistas.loc[atacadista['DATA'] == data]
n_atacadistas = len(n_atacadistas['ATACADISTA'].unique())
n_produtores = n_produtores.loc[produtores['DATA'] == data]
n_produtores = len(n_produtores['PRODUTOR'].unique())

print(f"DATA: {data[8:]}/{data[5:7]}/{data[0:4]}")
print(f"Atacadistas: {n_atacadistas}")
print(f"Produtores: {n_produtores}")
print(f"Total: {n_atacadistas + n_produtores}")
# Out:
# DATA: 23/07/2024
# Atacadistas: 79
# Produtores: 278
# Total: 357

# %% [markdown]
# ## Pesquisas diversas
# <hr>

# %%
pesquisa = produtores.loc[produtores['PRODUTOR'] == "0100331-ELI JOAO SONDA"]
pesquisa

# %%
dados = pd.read_parquet("Dados Comercializacao.parquet")

# %%
# 04501-ALFACE
# 07404-TOMATE CAQUI LONGA VIDA
# 07701-BATATA INGLESA
dados = cotacoes.loc[cotacoes['DATA'] >= '2024-05-01' and cotacoes['DATA'] <= '2024-05-31']
dados
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10872\2532657602.py in ?()
#       1 # 04501-ALFACE
#       2 # 07404-TOMATE CAQUI LONGA VIDA
#       3 # 07701-BATATA INGLESA
# ----> 4 dados = cotacoes.loc[cotacoes['DATA'] >= '2024-05-01' and cotacoes['DATA'] <= '2024-05-31']
#       5 dados
#
# ~\Desktop\Repositorio\CEASA-GETEC-Dados\venv-gertec\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
