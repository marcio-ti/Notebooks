# %%
import pandas as pd
import locale
pd.options.display.float_format = '{:.2f}'.format
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
import plotly.graph_objects as go
import json
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')
# Out:
# 'pt_BR.UTF-8'

# %%
json_data = {"data" : [
    {
      "Período": "2021-01",
      "volume": 53970031.5
    },
    {
      "Período": "2021-02",
      "volume": 50464322.3
    },
    {
      "Período": "2021-03",
      "volume": 56638875.0
    },
    {
      "Período": "2021-04",
      "volume": 49837843.0
    },
    {
      "Período": "2021-05",
      "volume": 45833053.7
    },
    {
      "Período": "2021-06",
      "volume": 46299200.5
    },
    {
      "Período": "2021-07",
      "volume": 45569177.4
    },
    {
      "Período": "2021-08",
      "volume": 48666877.5
    },
    {
      "Período": "2021-09",
      "volume": 47735162.8
    },
    {
      "Período": "2021-10",
      "volume": 46375192.1
    },
    {
      "Período": "2021-11",
      "volume": 53095645.5
    },
    {
      "Período": "2021-12",
      "volume": 60186650.9
    },
    {
      "Período": "2022-01",
      "volume": 55720807.3
    },
    {
      "Período": "2022-02",
      "volume": 46137200.7
    },
    {
      "Período": "2022-03",
      "volume": 49097668.1
    },
    {
      "Período": "2022-04",
      "volume": 42814866.4
    },
    {
      "Período": "2022-05",
      "volume": 45614676.5
    },
    {
      "Período": "2022-06",
      "volume": 44666507.3
    },
    {
      "Período": "2022-07",
      "volume": 41445718.4
    },
    {
      "Período": "2022-08",
      "volume": 47255337.6
    },
    {
      "Período": "2022-09",
      "volume": 45216865.9
    },
    {
      "Período": "2022-10",
      "volume": 46422256.4
    },
    {
      "Período": "2022-11",
      "volume": 44563633.6
    },
    {
      "Período": "2022-12",
      "volume": 51662852.8
    },
    {
      "Período": "2023-01",
      "volume": 49515283.41
    },
    {
      "Período": "2023-02",
      "volume": 44432671.49
    },
    {
      "Período": "2023-03",
      "volume": 48248150.94
    },
    {
      "Período": "2023-04",
      "volume": 39175088.34
    },
    {
      "Período": "2023-05",
      "volume": 44456496.42
    },
    {
      "Período": "2023-06",
      "volume": 41762960.17
    },
    {
      "Período": "2023-07",
      "volume": 45424548.87
    },
    {
      "Período": "2023-08",
      "volume": 46995278.54
    },
    {
      "Período": "2023-09",
      "volume": 40872600.64
    },
    {
      "Período": "2023-10",
      "volume": 47600556.64
    },
    {
      "Período": "2023-11",
      "volume": 46971504.72
    },
    {
      "Período": "2023-12",
      "volume": 46669776.48
    }
  ]
}

# %%
dados = pd.DataFrame.from_dict(pd.json_normalize(json_data['data']), orient='columns')
dados['MM3'] = dados['volume'].rolling(3).mean()
dados['MM5'] = dados['volume'].rolling(5).mean()
dados
# Out:
#     Período      volume         MM3         MM5
# 0   2021-01 53970031.50         NaN         NaN
# 1   2021-02 50464322.30         NaN         NaN
# 2   2021-03 56638875.00 53691076.27         NaN
# 3   2021-04 49837843.00 52313680.10         NaN
# 4   2021-05 45833053.70 50769923.90 51348825.10
# 5   2021-06 46299200.50 47323365.73 49814658.90
# 6   2021-07 45569177.40 45900477.20 48835629.92
# 7   2021-08 48666877.50 46845085.13 47241230.42
# 8   2021-09 47735162.80 47323739.23 46820694.38
# 9   2021-10 46375192.10 47592410.80 46929122.06
# 10  2021-11 53095645.50 49068666.80 48288411.06
# 11  2021-12 60186650.90 53219162.83 51211905.76
# 12  2022-01 55720807.30 56334367.90 52622691.72
# 13  2022-02 46137200.70 54014886.30 52303099.30
# 14  2022-03 49097668.10 50318558.70 52847594.50
# 15  2022-04 42814866.40 46016578.40 50791438.68
# 16  2022-05 45614676.50 45842403.67 47877043.80
# 17  2022-06 44666507.30 44365350.07 45666183.80
# 18  2022-07 41445718.40 43908967.40 44727887.34
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dados['Período'], y=dados['volume'],
                    mode='lines',
                    name='Volume'))
fig.add_trace(go.Scatter(x=dados['Período'], y=dados['MM3'],
                    mode='lines',
                    name='MM3',
                    
                    )
              )
fig.add_trace(go.Scatter(x=dados['Período'], y=dados['MM5'],
                    mode='lines',
                    name='MM5',
                         ))

fig.update_layout(
    title='Volume Mensal Comercializado de 2021 à 2023',
    xaxis_title='Mês/Ano',
    yaxis_title='Volume',
    
    xaxis=dict(
        showline=True,
        showgrid=False,
        showticklabels=True,
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    yaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
    ),
    margin=dict(
        autoexpand=False,
        l=50,
        r=20,
        t=110,
    ),
    plot_bgcolor='white'
)

    
fig.show()
# Out:
# <div>                            <div id="c23485cb-7bb2-4918-8294-9298e862a5dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c23485cb-7bb2-4918-8294-9298e862a5dc")) {                    Plotly.newPlot(                        "c23485cb-7bb2-4918-8294-9298e862a5dc",                        [{"mode":"lines","name":"Volume","x":["2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08","2023-09","2023-10","2023-11","2023-12"],"y":[53970031.5,50464322.3,56638875.0,49837843.0,45833053.7,46299200.
# ...
