# %%
import json
import geopandas as gpd
import pandas as pd
from pandas import json_normalize
from shapely.geometry import LineString

# %%
# Abrir e carregar o arquivo JSON
with open('canoas.json', 'r') as file:
	data = json.load(file)

# Se o JSON tiver uma lista de 'features'
features = data.get('features', [])  # Extraímos a lista se ela estiver sob a chave 'features'

# Normalizar os dados para criar o DataFrame
dados = pd.json_normalize(features)

dados
# Out:
#           type geometry.type  \
# 0      Feature    LineString
# 1      Feature    LineString
# 2      Feature    LineString
# 3      Feature    LineString
# 4      Feature    LineString
# ...        ...           ...
# 14710  Feature    LineString
# 14711  Feature    LineString
# 14712  Feature    LineString
# 14713  Feature    LineString
# 14714  Feature    LineString
#
#                                     geometry.coordinates properties.CD_SETOR  \
# 0      [[-51.1818953697, -29.9187659753], [-51.181827...    430460605000001P
# 1      [[-51.1819632287, -29.9189705166], [-51.182267...    430460605000001P
# 2      [[-51.1822675051, -29.9182618528], [-51.182389...    430460605000001P
# 3      [[-51.1799813689, -29.9181279415], [-51.182206...    430460605000001P
# 4      [[-51.1800255887, -29.9186081038], [-51.179981...    430460605000001P
# ...                                                  ...                 ...
# ...
