# %%
import pandas as pd

encodes = ['utf-8', 'iso-8859-1', 'latin-1','utf-8-sig']

# %%
for encode in encodes:
    try:
        dados = pd.read_csv(r"C:\Users\Marcio\Repositorio\GeoProcessamento\Dados Tabulares\Eleições 2024.csv", sep=";", encoding=encode)
        print(encode)
        break
    except Exception as e:
	    print(e)
# Out:
# 'utf-8' codec can't decode byte 0xe7 in position 4: invalid continuation byte
# iso-8859-1

# %%
df = dados.copy(deep=True)
df
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0        09/10/2024   16:36:29         2024                0
# 1        09/10/2024   16:36:29         2024                0
# 2        09/10/2024   16:36:29         2024                0
# 3        09/10/2024   16:36:29         2024                0
# 4        09/10/2024   16:36:29         2024                0
# ...             ...        ...          ...              ...
# 1947987  09/10/2024   16:36:29         2024                0
# 1947988  09/10/2024   16:36:29         2024                0
# 1947989  09/10/2024   16:36:29         2024                0
# 1947990  09/10/2024   16:36:29         2024                0
# 1947991  09/10/2024   16:36:29         2024                0
#
#            NM_TIPO_ELEICAO  CD_PLEITO            DT_PLEITO  NR_TURNO  \
# 0        Eleição Ordinária        452  2024-10-06 00:00:00         1
# 1        Eleição Ordinária        452  2024-10-06 00:00:00         1
# ...

# %%
poa = df.loc[df['CD_MUNICIPIO'] == 'PORTO ALEGRE']
poa.to_csv(r"C:\Users\Marcio\Repositorio\GeoProcessamento\Dados Tabulares\Eleições POA 2024.csv", sep=";", encoding='utf-8', index=False)
